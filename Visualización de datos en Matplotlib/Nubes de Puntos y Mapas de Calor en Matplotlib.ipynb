# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("C:/Users/usuario/Desktop/archivos_base_python_data_science_big_data_esencial/basedatos2008.csv")
df.dropna(inplace=True, subset=["ArrDelay","DepDelay","Distance","AirTime"])

sns.set(rc={"figure.figsize":(15,10)})

# %%
df2 = df[df["Origin"].isin(["ATL","HOU","IND"])].sample(frac=1).head(1000)

sns.jointplot(df2["DepDelay"],df2["ArrDelay"])
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df3 = df2[np.abs(df2["DepDelay"])<40]
df3 = df3[np.abs(df3["ArrDelay"])<40]

# %%
sns.jointplot(df3["DepDelay"],df3["ArrDelay"],kind="hex")
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(df3["DepDelay"],df3["ArrDelay"],kind="kde")
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
gb_df = pd.DataFrame(df2.groupby(["Origin","Month"],as_index=False)["DepDelay"].mean())
gb_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-4b1ff1f979b1> in <module>
# ----> 1 gb_df = pd.DataFrame(df2.goupby(["Origin","Month"],as_index=False)["DepDelay"].mean())
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'goupby'

# %%
data = gb_df.pivot("Month","Origin","DepDelay")
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-b257aff4e5b8> in <module>
# ----> 1 data = gb_df.pivot("Month","Origin","DepDelay")
#       2 data
#
# NameError: name 'gb_df' is not defined

# %%
sns.set(rc={"figure.figsize":(15,8)})
sns.heatmap(data=data, annot=True,linewidths=.5)
